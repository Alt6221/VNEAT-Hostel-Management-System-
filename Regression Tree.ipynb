# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Wind.csv')
df = df.dropna()
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# 1             39.0          E          W           4.0  ...           36
# 2             85.0          N        NNE           6.0  ...           69
# 3             54.0        WNW          W          30.0  ...           56
# 4             50.0        SSE        ESE          20.0  ...           49
# ..             ...        ...        ...           ...  ...          ...
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1019.7       1015.0         7         7     14.4     23.6
# 1         1012.4       1008.4         5         3     17.5     25.7
# 2         1009.5       1007.2         8         7     15.4     20.2
# 3         1005.5       1007.0         2         7     13.5     14.1
# 4         1018.3       1018.5         7         7     11.1     15.4
# ..           ...          ...       ...       ...      ...      ...
# 361       1016.1       1010.8         1         3     20.4     30.0
# 362       1020.0       1016.9         0         1     17.2     28.2
# 363       1024.0       1022.8         3         2     14.5     18.3
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 0           No      3.6          Yes
# 1          Yes      3.6          Yes
# 2          Yes     39.8          Yes
# 3          Yes      2.8          Yes
# 4          Yes      0.0           No
# ..         ...      ...          ...
# 361         No      0.0           No
# 362         No      0.0           No
# 363         No      0.0           No
# 364         No      0.0           No
# 365         No      0.0           No
#
# [328 rows x 22 columns]

# %%
from sklearn import preprocessing
sti = preprocessing.LabelEncoder()
df = df.apply(sti.fit_transform)
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         90      111         0           15        43            7
# 1        138      130        16           20        75            1
# 2        135      106        16           27        24            7
# 3        133       42        43           34        69            7
# 4         86       46        13           26        84           10
# ..       ...      ...       ...          ...       ...          ...
# 361      100      152         0           36        99            6
# 362       81      141         0           51       104            3
# 363      125       78         0           40        36            2
# 364      125      130         0           23        50            7
# 365      123      150         0           28       103            7
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0                8          12           7             2  ...           15
# 1               12           0          13             1  ...           22
# 2               33           3           5             2  ...           55
# 3               20          14          13            15  ...           42
# 4               18          10           2            10  ...           35
# ..             ...         ...         ...           ...  ...          ...
# 361             29          10           7             3  ...            2
# 362             17           6           6             0  ...            8
# 363             14           1           1             5  ...           33
# 364             16          11          14             2  ...           25
# 365             30           7          14            16  ...            0
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0             93           82         7         7       95      129
# 1             37           27         5         3      123      145
# 2             20           22         8         7      103       99
# 3              7           21         2         7       88       50
# 4             84          113         7         7       68       60
# ..           ...          ...       ...       ...      ...      ...
# 361           64           46         1         3      148      167
# 362           95           98         0         1      120      160
# 363          131          147         3         2       96       81
# 364          103           91         6         7      107      146
# 365           21           34         1         1      165      163
#
#      RainToday  RISK_MM  RainTomorrow
# 0            0       16             1
# 1            1       16             1
# 2            1       43             1
# 3            1       13             1
# 4            1        0             0
# ..         ...      ...           ...
# 361          0        0             0
# 362          0        0             0
# 363          0        0             0
# 364          0        0             0
# 365          0        0             0
#
# [328 rows x 22 columns]

# %%
featured_cols = ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']
x = df[featured_cols]
y = df.RainTomorrow
x
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  WindGustSpeed  WindSpeed9am  \
# 0         90      111         0           15              8             2
# 1        138      130        16           20             12             1
# 2        135      106        16           27             33             2
# 3        133       42        43           34             20            15
# 4         86       46        13           26             18            10
# ..       ...      ...       ...          ...            ...           ...
# 361      100      152         0           36             29             3
# 362       81      141         0           51             17             0
# 363      125       78         0           40             14             5
# 364      125      130         0           23             16             2
# 365      123      150         0           28             30            16
#
#      WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0               9           29           15           93           82
# 1               7           41           22           37           27
# 2               1           43           55           20           22
# 3              11           23           42            7           21
# 4              13           29           35           84          113
# ..            ...          ...          ...          ...          ...
# 361            22            1            2           64           46
# 362             8            6            8           95           98
# 363             3           24           33          131          147
# 364            13           30           25          103           91
# 365            17            4            0           21           34
#
#      Cloud9am  Cloud3pm  Temp9am  Temp3pm
# 0           7         7       95      129
# 1           5         3      123      145
# 2           8         7      103       99
# 3           2         7       88       50
# 4           7         7       68       60
# ..        ...       ...      ...      ...
# 361         1         3      148      167
# 362         0         1      120      160
# 363         3         2       96       81
# 364         6         7      107      146
# 365         1         1      165      163
#
# [328 rows x 15 columns]

# %%
x.dtypes
# Out:
# MinTemp          int64
# MaxTemp          int64
# Rainfall         int64
# Evaporation      int64
# WindGustSpeed    int64
# WindSpeed9am     int64
# WindSpeed3pm     int64
# Humidity9am      int64
# Humidity3pm      int64
# Pressure9am      int64
# Pressure3pm      int64
# Cloud9am         int64
# Cloud3pm         int64
# Temp9am          int64
# Temp3pm          int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.tree import DecisionTreeRegressor

rain = DecisionTreeRegressor(random_state=100)
rain.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=100)

# %%
y_pred = rain.predict(x_test)
result = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
result
# Out:
#      Actual  Predicted
# 160       0        0.0
# 277       0        0.0
# 185       0        0.0
# 37        0        1.0
# 40        0        0.0
# ..      ...        ...
# 141       0        0.0
# 356       0        0.0
# 136       0        0.0
# 343       0        0.0
# 27        0        0.0
#
# [99 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
print("Acurracy: ", accuracy_score(y_test, y_pred))
# Out:
# Acurracy:  0.8484848484848485

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[73  5]
#  [10 11]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        78
#            1       0.69      0.52      0.59        21
#
#     accuracy                           0.85        99
#    macro avg       0.78      0.73      0.75        99
# weighted avg       0.84      0.85      0.84        99

# %%
import graphviz 
from sklearn.tree import export_graphviz
import six
import sys
sys.modules['sklearn.externals.six'] = six
from six import StringIO
import pydotplus
from IPython.display import Image
dot_data = StringIO()

# %%
export_graphviz(rain, out_file=dot_data, filled=True, rounded=True, special_characters=True,feature_names=featured_cols,class_names=['0','1'])

# %%
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
Image(graph.create_png())
